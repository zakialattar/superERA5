# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
from utils import * 
import xarray

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
# Out:
# 2022-12-20 13:25:18.033116: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Define paths to training and test data
cwd = os.getcwd()
train_path = "data/train/"
test_path = "data/test/"

# Training set
train_files = ["mantua_pt"]
x_train_xr, x_length  = prepare_predictor(train_files,train_path)
y_train_xr, y_length  = prepare_predictand(train_files,train_path)

# Test set
x_test_xr, _ = prepare_predictor('water_pt', data_path=test_path,time_reindex=False)
y_test_xr, _ = prepare_predictand('water_pt',data_path=test_path,time_reindex=False)

#dataframes
x_train_df = x_train_xr.to_dataframe().drop("expver",axis=1).fillna(0)
x_train_df.ssrd  = x_train_df.ssrd /3600
x_test_df = x_test_xr.to_dataframe().drop("expver",axis=1).fillna(0)
x_test_df.ssrd  = x_test_df.ssrd /3600

y_train_df = y_train_xr.to_dataframe().fillna(0)
y_train_df["res"] = y_train_df.poa - x_train_df.ssrd.values
y_train_df = y_train_df.drop("poa",axis=1)

y_test_df = y_test_xr.to_dataframe().fillna(0)
y_test_df["res"] = y_test_df.poa - x_test_df.ssrd.values
y_test_df = y_test_df.drop("poa",axis=1)

# %%
# Standardization
x_mean, x_std = x_train_df.mean(), x_train_df.std()

x_train_df_std   = (x_train_df - x_mean)/x_std
x_test_df_std    = (x_test_df - x_mean)/x_std

y_mean, y_std = y_train_df.mean(), y_train_df.std()

y_train_df_std   = (y_train_df - y_mean)/y_std
y_test_df_std    = (y_test_df - y_mean)/y_std


x_train = x_train_df_std.to_numpy()
y_train = y_train_df_std.to_numpy()
x_test = x_test_df_std.to_numpy()
y_test = y_test_df_std.to_numpy()

print("Before shifting values:")
print(x_train.shape,y_train.shape)
print(x_test.shape, y_test.shape)

start = np.cumsum(x_length) - x_length
end   = np.cumsum(x_length)

slider = 24
x_train_all = []
y_train_all = []

for i in range(len(x_length)):
    
    x_subset = x_train[start[i]:end[i],:]
    y_subset = y_train[start[i]:end[i],:]
    
    x_subset = np.array([x_subset[i:i+slider] for i in range(0, x_length[i]-slider+1)])
    y_subset = np.array([[y_subset[i+slider-1]] for i in range(0, x_length[i]-slider+1)])
    
    x_train_all.append(x_subset)
    y_train_all.append(y_subset)
    
x_train = np.concatenate(x_train_all,axis=0)
y_train = np.concatenate(y_train_all,axis=0)
x_test  = np.array([x_test[i:i+slider] for i in range(0, x_test.shape[0]-slider+1)])
y_test  = np.array([y_test[i:i+slider] for i in range(0, y_test.shape[0]-slider+1)])

print("\nAfter shfting time:")
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# Before shifting values:
# (11191, 3) (11191, 1)
# (11191, 3) (11191, 1)
#
# After shfting time:
# (11168, 24, 3) (11168, 1, 1)
# (11168, 24, 3) (11168, 24, 1)

# %%
# set hyperparameters
n_neuron       = 64
activation     = 'relu'
num_epochs     = 50
learning_rate  = 0.001
minibatch_size = 128
model_num      = 1

# Build and compile the model
model = Sequential()
model.add(LSTM(n_neuron,input_shape=(x_train.shape[1],x_train.shape[2]),
               return_sequences=True,activation=activation))
model.add(LSTM(n_neuron,return_sequences=False,activation=activation))
model.add(Dense(n_neuron,activation=activation))
model.add(Dense(y_train.shape[-1],activation='linear')) 

model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

model.summary()


## Train the model
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)

print('\nInital test eval on different site:')
model.evaluate(x_test, y_test)

history = model.fit(x_train, y_train, 
                        batch_size = minibatch_size,
                        epochs = num_epochs,
                        validation_split=0.8,
                        callbacks=[early_stop],
                        shuffle=False)

print('\nFinal test eval on different site:')
model.evaluate(x_test, y_test)
plot_history(history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 24, 64)            17408
#
#  lstm_11 (LSTM)              (None, 64)                33024
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 54,657
# Trainable params: 54,657
# Non-trainable params: 0
# _________________________________________________________________
#
# Inital test eval on different site:
# 349/349 [==============================] - 2s 4ms/step - loss: 1.5827
# Epoch 1/50
# 18/18 [==============================] - 3s 81ms/step - loss: 1.1088 - val_loss: 0.9727
# Epoch 2/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0923 - val_loss: 0.9749
# Epoch 3/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0921 - val_loss: 0.9767
# Epoch 4/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0883 - val_loss: 0.9802
# Epoch 5/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0855 - val_loss: 0.9845
# Epoch 6/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0821 - val_loss: 0.9919
# Epoch 7/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0773 - val_loss: 1.0004
# Epoch 8/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0727 - val_loss: 1.0288
# Epoch 9/50
# 18/18 [==============================] - 1s 69ms/step - loss: 1.0657 - val_loss: 1.0629
# Epoch 10/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0658 - val_loss: 1.0502
# Epoch 11/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0530 - val_loss: 1.0720
# Epoch 12/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0519 - val_loss: 1.0675
# Epoch 13/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0348 - val_loss: 1.0957
# Epoch 14/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0257 - val_loss: 1.2830
# Epoch 15/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0429 - val_loss: 1.1280
# Epoch 16/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0624 - val_loss: 1.0670
# Epoch 17/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0728 - val_loss: 1.0212
# Epoch 18/50
# 18/18 [==============================] - 1s 69ms/step - loss: 1.0458 - val_loss: 1.0339
# Epoch 19/50
# 18/18 [==============================] - 1s 69ms/step - loss: 1.0307 - val_loss: 1.0892
# Epoch 20/50
# 18/18 [==============================] - 1s 69ms/step - loss: 1.0264 - val_loss: 1.2020
# Epoch 21/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0366 - val_loss: 4.7775
# Epoch 22/50
# 18/18 [==============================] - 1s 69ms/step - loss: 1.0546 - val_loss: 1.0151
# Epoch 23/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0564 - val_loss: 0.9884
# Epoch 24/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0441 - val_loss: 1.0354
# Epoch 25/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0450 - val_loss: 1.0351
# Epoch 26/50
# 18/18 [==============================] - 1s 70ms/step - loss: 0.9979 - val_loss: 1.0822
# Epoch 27/50
# 18/18 [==============================] - 1s 70ms/step - loss: 0.9726 - val_loss: 1.1843
# Epoch 28/50
# 18/18 [==============================] - 1s 70ms/step - loss: 1.0085 - val_loss: 1.0719
# Epoch 29/50
# 18/18 [==============================] - 1s 69ms/step - loss: 0.9550 - val_loss: 1.1485
# Epoch 30/50
# 18/18 [==============================] - 1s 70ms/step - loss: 0.9347 - val_loss: 1.1786
# Epoch 31/50
# 18/18 [==============================] - 1s 70ms/step - loss: 0.9475 - val_loss: 1.1438
#
# Final test eval on different site:
# 349/349 [==============================] - 1s 4ms/step - loss: 1.7028

# %%
# save the model
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)

# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
model.save(os.path.join(model_path,'LSTM_model.h5'))

# %%
# reload the saved model
model = load_model(os.path.join(model_path,'LSTM_model.h5'))

# %%
# Predict
y_test_pre = model.predict(x_test)
#plot the results
df_test = pd.DataFrame()
df_test["res"] = y_test_df.reset_index().res
df_test = df_test[slider-1:]
df_test["y_test_pre_res"] = y_test_pre* y_std.values[0] + y_mean.values[0]
df_plot = df_test[500:1000]
df_plot.plot(figsize=(10,5))
plt.xticks(rotation=45)
df_plot.head(20)
# Out:
# 349/349 [==============================] - 2s 4ms/step
#             res  y_test_pre_res
# 523  -10.652267      -37.922047
# 524   31.964879      -38.657051
# 525   62.117859      -23.538147
# 526   76.628546       -0.396968
# 527   75.202400       18.179068
# 528   64.103879       23.959673
# 529   68.280442       15.868103
# 530  161.007796       -5.413640
# 531   32.585692      -24.020508
# 532 -107.446654      -31.979153
# 533 -119.990025      -31.897234
# 534  -60.437707      -24.950302
# 535  -33.095113      -12.473136
# 536    7.922426       -1.431304
# 537    7.922426        5.521655
# 538    7.922426        7.571983
# 539    7.922426        7.844756
# 540    7.922426        6.645220
# 541    7.922426        5.737596
# 542    7.922426        3.428179

# %%
## Compare against actual Y - residual
plt.scatter(x=df_test.res,y=df_test.y_test_pre_res)
p1 = max(max(df_test.y_test_pre_res), max(df_test.res))
p2 = min(min(df_test.y_test_pre_res), min(df_test.res))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel("actual residual")
plt.ylabel("predicted residual")
plt.show()
print(p1)
# Out:
# 685.878306233724

# %%
#plot the results
df_test = pd.DataFrame()
df_test["ssrd"] = x_test_df.reset_index().ssrd
df_test["poa"] = y_test_df.reset_index().res + df_test.ssrd
df_test = df_test[slider-1:]
df_test["y_test_pre"] = y_test_pre* y_std.values[0] + y_mean.values[0]
df_test["y_test_pre"] = df_test["y_test_pre"] + df_test["ssrd"]
df_plot = df_test[500:1000]
df_plot.plot(figsize=(10,5))
plt.xticks(rotation=45)
df_plot.head(20)
# Out:
#            ssrd          poa   y_test_pre
# 523  262.544434   251.892167   224.622391
# 524  466.711121   498.676000   428.054077
# 525  658.377808   720.495667   634.839661
# 526  816.711121   893.339667   816.314148
# 527  925.044434  1000.246833   943.223511
# 528  979.211121  1043.315000  1003.170776
# 529  945.877808  1014.158250   961.745911
# 530  779.211121   940.218917   773.797485
# 531  720.877808   753.463500   696.857300
# 532  541.711121   434.264467   509.731964
# 533  362.544434   242.554408   330.647186
# 534  162.544449   102.106742   137.594147
# 535   54.211113    21.116000    41.737976
# 536    0.044444     7.966870    -1.386859
# 537    0.044444     7.966870     5.566100
# 538    0.044444     7.966870     7.616428
# 539    0.044444     7.966870     7.889201
# 540    0.044444     7.966870     6.689664
# 541    0.044444     7.966870     5.782040
# 542    0.044444     7.966870     3.472624

# %%
df_plot = df_test[1000:1500]
df_plot.plot(figsize=(10,5))
plt.xticks(rotation=45)
df_plot.head(20)
# Out:
#             ssrd         poa  y_test_pre
# 1023    0.044444    7.966870    1.595419
# 1024    0.044444    7.966870   -2.153233
# 1025    0.044444    8.538575   -7.019366
# 1026   12.544444   21.878267    0.438829
# 1027   37.544445   90.482208   21.507685
# 1028  104.211113  142.316250   85.156593
# 1029  154.211105  196.627750  133.018417
# 1030  270.877777  226.165583  248.783401
# 1031  487.544434  328.118833  465.109009
# 1032  645.877808  404.726583  624.048401
# 1033  641.711121  528.214333  622.287231
# 1034  645.877808  502.106167  630.235718
# 1035  520.877808  393.483167  508.868591
# 1036  412.544434  206.537167  403.351990
# 1037  195.877777  249.605250  189.446732
# 1038  112.544441  109.919992  108.010353
# 1039   37.544445   35.789633   35.575645
# 1040    0.044444    7.966870    0.937943
# 1041    0.044444    7.966870    3.291142
# 1042    0.044444    7.966870    4.934353

# %%
# Compare against original x values
plt.scatter(df_test.ssrd,df_test.y_test_pre)
plt.xlabel("X Actual")
plt.ylabel("Y Predicted")
# Out:
# Text(0, 0.5, 'Y Predicted')

# %%
# Compare against y actual
plt.scatter(df_test.poa,df_test.y_test_pre)
p1 = max(max(df_test.y_test_pre), max(df_test.poa))
p2 = min(min(df_test.y_test_pre), min(df_test.poa))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel("Y Actual")
plt.ylabel("Y Predicted")
# Out:
# Text(0, 0.5, 'Y Predicted')
