# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
from utils import * 
import xarray

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras import Sequential
import graphviz
import pydot

from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer

# %% [markdown]
# <h2>Prepare Training and Test Sets</h2>

# %%
## Define paths to training and test data
cwd = os.getcwd()
train_path = "data/train/"
test_path = "data/test/"

# Training set
train_files    = ["mantua_pt"]
X_train_xr, _  = prepare_predictor(train_files,train_path)
y_train_xr, _  = prepare_predictand(train_files,train_path)

# Test set
X_test_xr, _ = prepare_predictor('water_pt', data_path=test_path,time_reindex=False)
y_test_xr, _ = prepare_predictand('water_pt',data_path=test_path,time_reindex=False)

## Convert to numpy arrays and check to make sure shapes of each dataset match
X_train = X_train_xr["ssrd"].stack(dim=["latitude", "longitude"]).to_numpy()
X_train = np.where(np.isnan(X_train), 0, X_train)

X_test = X_test_xr["ssrd"].stack(dim=["latitude", "longitude"]).to_numpy()
X_test = np.where(np.isnan(X_test), 0, X_test)

y_train = y_train_xr["poa"].stack(dim=["latitude", "longitude"]).to_numpy()
y_train = np.where(np.isnan(y_train), 0, y_train)

y_test = y_test_xr["poa"].stack(dim=["latitude", "longitude"]).to_numpy()
y_test = np.where(np.isnan(y_test), 0, y_test)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (11191, 1) (11191, 1) (11191, 1) (11191, 1)

# %%
x_mean, x_std = X_train.mean(), X_train.std()

X_train_std = (X_train - x_mean) / x_std
X_test_std = (X_test - x_mean) / x_std

y_mean, y_std = y_train.mean(), y_train.std()
y_train_std = (y_train - y_mean) / y_std
y_test_std = (y_test - y_mean) / y_std

print(X_train_std.shape,y_train_std.shape)
print(X_test_std.shape,y_test_std.shape)
# Out:
# (11191, 1) (11191, 1)
# (11191, 1) (11191, 1)

# %%
# set hyperparameters
n_neuron       = 32
activation     = 'relu'
num_epochs     = 50
learning_rate  = 0.005
minibatch_size = 32
model_num      = 1

#create the model
model = Sequential([
      keras.layers.Dense(n_neuron, activation="linear", input_shape=(X_train.shape[1],)),
      keras.layers.Dense(n_neuron, activation="exponential"),
      keras.layers.Dense(y_train.shape[1],  activation='linear')
])

model.compile(loss='mse',optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate))

print(model.summary())
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)


early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
print('\nInital test eval on different site:')
model.evaluate(X_test_std, y_test_std)

history = model.fit(X_train_std, y_train_std, 
                    batch_size      = minibatch_size,
                    epochs          = num_epochs,
                    validation_split = 0.5,
                    verbose         = 1,
                    callbacks       = [early_stop])

print('\nFinal test eval on different site:')
model.evaluate(X_test_std, y_test_std)
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_102 (Dense)           (None, 32)                64
#
#  dense_103 (Dense)           (None, 32)                1056
#
#  dense_104 (Dense)           (None, 1)                 33
#
# =================================================================
# Total params: 1,153
# Trainable params: 1,153
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Inital test eval on different site:
# 350/350 [==============================] - 0s 414us/step - loss: 6.5952
# Epoch 1/50
# 175/175 [==============================] - 0s 1ms/step - loss: 0.1405 - val_loss: 0.1062
# Epoch 2/50
# 175/175 [==============================] - 0s 948us/step - loss: 0.0955 - val_loss: 0.1057
# Epoch 3/50
# 175/175 [==============================] - 0s 932us/step - loss: 0.0945 - val_loss: 0.1265
# Epoch 4/50
# 175/175 [==============================] - 0s 931us/step - loss: 0.0948 - val_loss: 0.1112
# Epoch 5/50
# 175/175 [==============================] - 0s 927us/step - loss: 0.0942 - val_loss: 0.1127
# Epoch 6/50
# 175/175 [==============================] - 0s 924us/step - loss: 0.0956 - val_loss: 0.1054
# Epoch 7/50
# 175/175 [==============================] - 0s 921us/step - loss: 0.0946 - val_loss: 0.1061
# Epoch 8/50
# 175/175 [==============================] - 0s 934us/step - loss: 0.0946 - val_loss: 0.1114
# Epoch 9/50
# 175/175 [==============================] - 0s 925us/step - loss: 0.0955 - val_loss: 0.1093
# Epoch 10/50
# 175/175 [==============================] - 0s 931us/step - loss: 0.
# %%
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)

# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
model.save(os.path.join(model_path,'NN_model.h5'))

# reload the saved model
model = load_model(os.path.join(model_path,'NN_model.h5'))


#y_Test 
y_test_predict = model.predict(X_test_std)

df_test = pd.DataFrame()
df_test["x_test"] = X_test[:, 0]/3600
df_test["y_test_std"] = y_test_std[:, 0]
df_test["y_test_predict_std"] = y_test_predict
df_test["y_test"] = y_test[:, 0]
df_test["y_test_predict"] = y_test_predict * y_std + y_mean

df_plot = df_test[0:100]
df_plot.head(20)
# Out:
# 350/350 [==============================] - 0s 374us/step
#         x_test  y_test_std  y_test_predict_std      y_test  y_test_predict
# 0   825.044434    1.836252            2.297796  679.905000      804.082336
# 1   741.711121    0.910504            1.972979  430.834050      716.690918
# 2   229.211105    0.595311            0.164874  346.032058      230.223694
# 3   325.044434    0.061962            0.496248  202.535400      319.379395
# 4   491.711121    0.709347            1.070246  376.713250      473.812378
# 5   379.211121    0.079670            0.682316  207.299592      369.440613
# 6   158.377777   -0.491928           -0.084160   53.512333      163.221588
# 7    16.711111   -0.635713           -0.601206   14.827285       24.111282
# 8     0.044444   -0.661212           -0.664275    7.966870        7.142670
# 9     0.044444   -0.661212           -0.664275    7.966870        7.142670
# 10    0.044444   -0.661212           -0.664275    7.966870        7.142670
# 11    0.044444   -0.661212           -0.664275    7.966870        7.142670
# 12    0.044444   -0.661212           -0.664275    7.966870        7.142670
# 13    0.044444   -0.661212           -0.664275    7.966870        7.142670
# 14    0.044444   -0.661212           -0.664275    7.966870        7.142670
# 15    0.044444   -0.661212           -0.664275    7.966870        7.142670
# 16    0.044444   -0.661212           -0.664275    7.966870        7.142670
# 17    0.044444   -0.661212           -0.664275    7.966870        7.142670
# 18   29.211111   -0.580465           -0.554260   29.691495       36.742065
# 19  200.044449    0.078907            0.062890  207.094469      202.785080

# %%
df_plot = df_test[0:100]
plt.plot(df_plot.x_test,label="era5")
plt.plot(df_plot.y_test,label="y_actual")
plt.plot(df_plot.y_test_predict,label="y_predicted")
plt.xlabel("time")
plt.legend()
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
df_plot
# Out:
#         x_test  y_test_std  y_test_predict_std      y_test  y_test_predict
# 0   825.044434    1.836252            2.281298  679.905000      799.643677
# 1   741.711121    0.910504            2.016472  430.834050      728.392700
# 2   229.211105    0.595311            0.107192  346.032058      214.704422
# 3   325.044434    0.061962            0.417628  202.535400      298.226776
# 4   491.711121    0.709347            1.050499  376.713250      468.499390
# ..         ...         ...                 ...         ...             ...
# 95  725.044434    1.033747            1.958824  463.992500      712.882690
# 96  416.711121    1.844045            0.754298  682.001583      388.807068
# 97  391.711121    1.137868            0.659126  492.006000      363.201355
# 98  416.711121    0.339616            0.754298  277.237583      388.807068
# 99  304.211121    1.071288            0.346124  474.092833      278.988586
#
# [100 rows x 5 columns]

# %%
plt.scatter(x=df_test.y_test,y=df_test.y_test_predict)
p1 = max(max(df_test.y_test_predict), max(df_test.y_test))
p2 = min(min(df_test.y_test_predict), min(df_test.y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.ylabel("Y Predicted")
plt.xlabel("Y Actual")
plt.show()
print(p1)
# Out:
# 1091.91

# %%
plt.figure(figsize=(10,4))
df_plot = df_test[0:200]
plt.plot(df_plot.y_actual,label="actual")
plt.plot(df_plot.y_predict,label="predict")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [122], in <cell line: 3>()
#       1 plt.figure(figsize=(10,4))
#       2 df_plot = df_test[0:200]
# ----> 3 plt.plot(df_plot.y_actual,label="actual")
#       4 plt.plot(df_plot.y_predict,label="predict")
#       5 plt.legend()
#
# File ~/opt/anaconda3/envs/EEE/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'y_actual'
