# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
from utils import * 
import xarray as xr
import datetime as dt
from datetime import timedelta

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
# Out:
# 2022-12-22 21:47:08.072905: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Define paths to training and test data
cwd = os.getcwd()
train_path = "data/train/"
test_path = "data/test/"

# Training set
train_files = ["mantua_pt","staten_pt","west_pt"]
x_train_xr, x_length  = prepare_predictor(train_files,train_path,time_reindex=False)
y_train_xr, y_length  = prepare_predictand(train_files,train_path,time_reindex=False)

# Test set
x_test_xr, _ = prepare_predictor('water_pt', data_path=test_path,time_reindex=False)
y_test_xr, _ = prepare_predictand('water_pt',data_path=test_path,time_reindex=False)

#dataframes
x_train_df = x_train_xr.to_dataframe().drop(["expver"],axis=1).reset_index().dropna()
x_train_df.ssrd = x_train_df.ssrd / 3600
x_train_df = x_train_df.set_index(["time"])

x_test_df = x_test_xr.to_dataframe().drop(["expver"],axis=1).fillna(0).reset_index()
x_test_df.ssrd = x_test_df.ssrd / 3600
x_test_df = x_test_df.set_index(["time"])

y_train_df = y_train_xr.to_dataframe().dropna()
y_test_df = y_test_xr.to_dataframe().dropna()

# %%
# Standardization
x_mean, x_std = x_train_df.mean(), x_train_df.std()

x_train_df_std   = (x_train_df - x_mean)/x_std
x_test_df_std    = (x_test_df - x_mean)/x_std

y_mean, y_std = y_train_df.mean(), y_train_df.std()

y_train_df_std   = (y_train_df - y_mean)/y_std
y_test_df_std    = (y_test_df - y_mean)/y_std


x_train = x_train_df_std.to_numpy()
y_train = y_train_df_std.to_numpy()
x_test = x_test_df_std.to_numpy()
y_test = y_test_df_std.to_numpy()

print("Before shifting values:")
print(x_train.shape,y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# Before shifting values:
# (30022, 4) (30022, 1)
# (11191, 4) (11191, 1)

# %%
# set hyperparameters
n_neuron       = 256
activation     = 'relu'
num_epochs     = 50
learning_rate  = 0.001
minibatch_size = 128
model_num      = 1

# Build and compile the model
model = Sequential()
model.add(Dense(n_neuron, activation=activation, input_shape=(x_train.shape[1],)))
model.add(Dense(n_neuron,activation=activation))
model.add(Dense(n_neuron,activation=activation))
model.add(Dense(y_train.shape[-1],activation='linear'))
model.compile(loss='mse',optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate))

model.summary()


## Train the model
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

print('\nInital test eval on different site:')
model.evaluate(x_test, y_test)

history = model.fit(x_train, y_train, 
                        batch_size = minibatch_size,
                        epochs = num_epochs,
                        validation_split=0.8,
                        callbacks=[early_stop],
                        shuffle=False)

print('\nFinal test eval on different site:')
model.evaluate(x_test, y_test)
plot_history(history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 256)               1280
#
#  dense_20 (Dense)            (None, 256)               65792
#
#  dense_21 (Dense)            (None, 256)               65792
#
#  dense_22 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 133,121
# Trainable params: 133,121
# Non-trainable params: 0
# _________________________________________________________________
#
# Inital test eval on different site:
# 350/350 [==============================] - 0s 603us/step - loss: 1.2182
# Epoch 1/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.9988 - val_loss: 0.9484
# Epoch 2/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.9561 - val_loss: 0.9181
# Epoch 3/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.9185 - val_loss: 0.8892
# Epoch 4/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.8837 - val_loss: 0.8610
# Epoch 5/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.8503 - val_loss: 0.8330
# Epoch 6/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.8185 - val_loss: 0.8058
# Epoch 7/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7889 - val_loss: 0.7795
# Epoch 8/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7615 - val_loss: 0.7538
# Epoch 9/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7358 - val_loss: 0.7287
# Epoch 10/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7118 - val_loss: 0.7045
# Epoch 11/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6895 - val_loss: 0.6813
# Epoch 12/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6692 - val_loss: 0.6593
# Epoch 13/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6509 - val_loss: 0.6387
# Epoch 14/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6347 - val_loss: 0.6196
# Epoch 15/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6205 - val_loss: 0.6022
# Epoch 16/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6082 - val_loss: 0.5863
# Epoch 17/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5978 - val_loss: 0.5720
# Epoch 18/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5890 - val_loss: 0.5594
# Epoch 19/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5817 - val_loss: 0.5482
# Epoch 20/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5755 - val_loss: 0.5384
# Epoch 21/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5704 - val_loss: 0.5299
# Epoch 22/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5661 - val_loss: 0.5225
# Epoch 23/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5625 - val_loss: 0.5161
# Epoch 24/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5593 - val_loss: 0.5107
# Epoch 25/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5566 - val_loss: 0.5059
# Epoch 26/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5543 - val_loss: 0.5019
# Epoch 27/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5521 - val_loss: 0.4984
# Epoch 28/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5501 - val_loss: 0.4953
# Epoch 29/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5483 - val_loss: 0.4927
# Epoch 30/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5467 - val_loss: 0.4904
# Epoch 31/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5451 - val_loss: 0.4884
# Epoch 32/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5436 - val_loss: 0.4866
# Epoch 33/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5421 - val_loss: 0.4850
# Epoch 34/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5408 - val_loss: 0.4836
# Epoch 35/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5394 - val_loss: 0.4822
# Epoch 36/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5381 - val_loss: 0.4810
# Epoch 37/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5369 - val_loss: 0.4799
# Epoch 38/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5357 - val_loss: 0.4788
# Epoch 39/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5346 - val_loss: 0.4778
# Epoch 40/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5335 - val_loss: 0.4768
# Epoch 41/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5324 - val_loss: 0.4759
# Epoch 42/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5314 - val_loss: 0.4750
# Epoch 43/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5304 - val_loss: 0.4742
# Epoch 44/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5294 - val_loss: 0.4734
# Epoch 45/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5285 - val_loss: 0.4726
# Epoch 46/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5275 - val_loss: 0.4719
# Epoch 47/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5267 - val_loss: 0.4711
# Epoch 48/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5259 - val_loss: 0.4704
# Epoch 49/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5251 - val_loss: 0.4697
# Epoch 50/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5243 - val_loss: 0.4690
#
# Final test eval on different site:
# 350/350 [==============================] - 0s 605us/step - loss: 0.2611

# %%
# save the model
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)

# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
model.save(os.path.join(model_path,'no_ssrd_model.h5'))

# %%
# reload the saved model
model = load_model(os.path.join(model_path,'no_ssrd_model.h5'))

# predict on the test set
y_test_pre = model.predict(x_test)
# Out:
# 350/350 [==============================] - 0s 565us/step

# %%
### STD
#plot the results
df_test = x_test_df_std.reset_index().drop(["lat","lon"],axis=1).set_index("time")
df_test["poa"] = y_test_df_std.reset_index().drop(["lat","lon"],axis=1).set_index("time").poa
df_test["y_test_pre"] = y_test_pre

df_plot = df_test[800:1000]
df_plot.plot(figsize=(10,5))
plt.xticks(rotation=45)
# Out:
# (array([450529, 450696, 450728]),
#  [Text(450529, 0, ''), Text(450696, 0, '01\nJun\n2021'), Text(450728, 0, '')])

# %%
# Predict
y_test_pre = model.predict(x_test)
df_test = x_test_df.reset_index().drop(["lat","lon","tcc"],axis=1).set_index("time")
df_test["poa"] = y_test_df.reset_index().drop(["lat","lon"],axis=1).set_index("time").poa
df_test["y_test_pre"] = y_test_pre* y_std.values[0] + y_mean.values[0]

df_plot = df_test
df_plot.plot(figsize=(10,5))
plt.xticks(rotation=45)
# Out:
# 350/350 [==============================] - 0s 557us/step
# (array([449729, 451416, 453624, 455832, 457992, 460176, 460919]),
#  [Text(449729, 0, ''),
#   Text(451416, 0, 'Jul'),
#   Text(453624, 0, 'Oct'),
#   Text(455832, 0, 'Jan\n2022'),
#   Text(457992, 0, 'Apr'),
#   Text(460176, 0, 'Jul'),
#   Text(460919, 0, '')])

# %%
# Compare against y actual
plt.scatter(df_test.poa,df_test.y_test_pre)
p1 = max(max(df_test.y_test_pre), max(df_test.poa))
p2 = min(min(df_test.y_test_pre), min(df_test.poa))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel("Y Actual")
plt.ylabel("Y Predicted")
# Out:
# Text(0, 0.5, 'Y Predicted')
