# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
from utils import * 
import xarray as xr
import datetime as dt
from datetime import timedelta
from tensorflow.keras import backend as K


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers

# %%
## Define paths to training and test data
cwd = os.getcwd()
train_path = "data/train/"
test_path = "data/test/"

# Training set
train_files = ["mantua_pt","staten_pt","west_pt"]
x_train_xr, x_length  = prepare_predictor(train_files,train_path,time_reindex=False)
y_train_xr, y_length  = prepare_predictand(train_files,train_path,time_reindex=False)

# Test set
x_test_xr, _ = prepare_predictor('water_pt', data_path=test_path,time_reindex=False)
y_test_xr, _ = prepare_predictand('water_pt',data_path=test_path,time_reindex=False)

#dataframes
x_train_df = x_train_xr.to_dataframe().drop(["expver"],axis=1).reset_index().dropna()
x_train_df.ssrd = x_train_df.ssrd / 3600
x_train_df = x_train_df.set_index(["time"])

x_test_df = x_test_xr.to_dataframe().drop(["expver"],axis=1).fillna(0).reset_index()
x_test_df.ssrd = x_test_df.ssrd / 3600
x_test_df = x_test_df.set_index(["time"])

y_train_df = y_train_xr.to_dataframe().dropna()
y_train_df.poa = y_train_df.poa / np.cos(0.174533) #convert to GHI
y_train_df["res"] = y_train_df.poa.values - x_train_df.ssrd.values

y_test_df = y_test_xr.to_dataframe().dropna()
y_test_df.poa = y_test_df.poa / np.cos(0.174533) #convert to GHI
y_test_df["res"] = y_test_df.poa - x_test_df.ssrd

# %%
# Standardization
x_mean, x_std = x_train_df.mean(), x_train_df.std()

x_train_df_std   = (x_train_df - x_mean)/x_std
x_test_df_std    = (x_test_df - x_mean)/x_std

y_mean, y_std = y_train_df.mean(), y_train_df.std()

y_train_df_std   = (y_train_df - y_mean)/y_std
y_test_df_std    = (y_test_df - y_mean)/y_std


x_train = x_train_df_std.to_numpy()
y_train = y_train_df_std.drop("poa",axis=1).to_numpy()
x_test = x_test_df_std.to_numpy()
y_test = y_test_df_std.drop("poa",axis=1).to_numpy()

print("Before shifting values:")
print(x_train.shape,y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# Before shifting values:
# (30022, 5) (30022, 1)
# (11191, 5) (11191, 1)

# %%
def QuantileLoss(perc, delta=1e-4):
    perc = np.array(perc).reshape(-1)
    perc.sort()
    perc = perc.reshape(1, -1)
    def _qloss(y, pred):
        I = tf.cast(y <= pred, tf.float32)
        d = K.abs(y - pred)
        correction = I * (1 - perc) + (1 - I) * perc
        # huber loss
        huber_loss = K.sum(correction * tf.where(d <= delta, 0.5 * d ** 2 / delta, d - 0.5 * delta), -1)
        # order loss
        q_order_loss = K.sum(K.maximum(0.0, pred[:, :-1] - pred[:, 1:] + 1e-6), -1)
        return huber_loss + q_order_loss
    return _qloss

# %%
# set hyperparameters
n_neuron       = 64
activation     = 'relu'
num_epochs     = 50
learning_rate  = 0.01
minibatch_size = 128
model_num      = 1

perc_points = [0.01,.25,.5,.75,.99]


# Build and compile the model
model = Sequential()
model.add(Dense(n_neuron, activation=activation, input_shape=(x_train.shape[1],)))
model.add(Dense(n_neuron, activation=activation))
model.add(Dense(y_train.shape[-1],activation='linear'))
model.compile(loss="mse",optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate))

model.summary()


## Train the model
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)

print('\nInital test eval on different site:')
model.evaluate(x_test, y_test)

history = model.fit(x_train, y_train, 
                        batch_size = minibatch_size,
                        epochs = num_epochs,
                        validation_split=0.2,
                        callbacks=[early_stop],
                        shuffle=False)

print('\nFinal test eval on different site:')
model.evaluate(x_test, y_test)
plot_history(history)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                384
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,609
# Trainable params: 4,609
# Non-trainable params: 0
# _________________________________________________________________
#
# Inital test eval on different site:
# 350/350 [==============================] - 0s 499us/step - loss: 1.6028
# Epoch 1/50
# 188/188 [==============================] - 0s 955us/step - loss: 0.9609 - val_loss: 1.1344
# Epoch 2/50
# 188/188 [==============================] - 0s 841us/step - loss: 0.9482 - val_loss: 1.1309
# Epoch 3/50
# 188/188 [==============================] - 0s 893us/step - loss: 0.9433 - val_loss: 1.1300
# Epoch 4/50
# 188/188 [==============================] - 0s 948us/step - loss: 0.9412 - val_loss: 1.1297
# Epoch 5/50
# 188/188 [==============================] - 0s 862us/step - loss: 0.9398 - val_loss: 1.1297
# Epoch 6/50
# 188/188 [==============================] - 0s 919us/step - loss: 0.9388 - val_loss: 1.1303
# Epoch 7/50
# 188/188 [==============================] - 0s 887us/step - loss: 0.9380 - val_loss: 1.1308
# Epoch 8/50
# 188/188 [==============================] - 0s 852us/step - loss: 0.9373 - val_loss: 1.1312
# Epoch 9/50
# 188/188 [==============================] - 0s 844us/step - loss: 0.9366 - val_loss: 1.1317
# Epoch 10/50
# 188/188 [==============================] - 0s 837us/step - loss: 0.9361 - val_loss: 1.1320
# Epoch 11/50
# 188/188 [==============================] - 0s 889us/step - loss: 0.9356 - val_loss: 1.1323
# Epoch 12/50
# 188/188 [==============================] - 0s 841us/step - loss: 0.9351 - val_loss: 1.1324
# Epoch 13/50
# 188/188 [==============================] - 0s 837us/step - loss: 0.9347 - val_loss: 1.1324
# Epoch 14/50
# 188/188 [==============================] - 0s 855us/step - loss: 0.9343 - val_loss: 1.1326
# Epoch 15/50
# 188/188 [==============================] - 0s 855us/step - loss: 0.9340 - val_loss: 1.1330
# Epoch 16/50
# 188/188 [==============================] - 0s 848us/step - loss: 0.9336 - val_loss: 1.1334
# Epoch 17/50
# 188/188 [==============================] - 0s 847us/step - loss: 0.9333 - val_loss: 1.1336
# Epoch 18/50
# 188/188 [==============================] - 0s 842us/step - loss: 0.9330 - val_loss: 1.1340
# Epoch 19/50
# 188/188 [==============================] - 0s 845us/step - loss: 0.9327 - val_loss: 1.1344
# Epoch 20/50
# 188/188 [==============================] - 0s 846us/step - loss: 0.9324 - val_loss: 1.1347
# Epoch 21/50
# 188/188 [==============================] - 0s 847us/step - loss: 0.9321 - val_loss: 1.1350
# Epoch 22/50
# 188/188 [==============================] - 0s 855us/step - loss: 0.9318 - val_loss: 1.1353
# Epoch 23/50
# 188/188 [==============================] - 0s 849us/step - loss: 0.9315 - val_loss: 1.1356
# Epoch 24/50
# 188/188 [==============================] - 0s 840us/step - loss: 0.9312 - val_loss: 1.1357
# Epoch 25/50
# 188/188 [==============================] - 0s 853us/step - loss: 0.9310 - val_loss: 1.1360
# Epoch 26/50
# 188/188 [==============================] - 0s 846us/step - loss: 0.9307 - val_loss: 1.1363
# Epoch 27/50
# 188/188 [==============================] - 0s 838us/step - loss: 0.9305 - val_loss: 1.1365
# Epoch 28/50
# 188/188 [==============================] - 0s 842us/step - loss: 0.9303 - val_loss: 1.1369
# Epoch 29/50
# 188/188 [==============================] - 0s 853us/step - loss: 0.9301 - val_loss: 1.1372
# Epoch 30/50
# 188/188 [==============================] - 0s 846us/step - loss: 0.9298 - val_loss: 1.1374
# Epoch 31/50
# 188/188 [==============================] - 0s 853us/step - loss: 0.9296 - val_loss: 1.1376
# Epoch 32/50
# 188/188 [==============================] - 0s 848us/step - loss: 0.9294 - val_loss: 1.1379
# Epoch 33/50
# 188/188 [==============================] - 0s 850us/step - loss: 0.9292 - val_loss: 1.1381
# Epoch 34/50
# 188/188 [==============================] - 0s 843us/step - loss: 0.9290 - val_loss: 1.1383
# Epoch 35/50
# 188/188 [==============================] - 0s 843us/step - loss: 0.9289 - val_loss: 1.1385
# Epoch 36/50
# 188/188 [==============================] - 0s 849us/step - loss: 0.9287 - val_loss: 1.1386
# Epoch 37/50
# 188/188 [==============================] - 0s 838us/step - loss: 0.9286 - val_loss: 1.1387
# Epoch 38/50
# 188/188 [==============================] - 0s 844us/step - loss: 0.9284 - val_loss: 1.1389
# Epoch 39/50
# 188/188 [==============================] - 0s 853us/step - loss: 0.9283 - val_loss: 1.1390
# Epoch 40/50
# 188/188 [==============================] - 0s 840us/step - loss: 0.9281 - val_loss: 1.1391
# Epoch 41/50
# 188/188 [==============================] - 0s 851us/step - loss: 0.9279 - val_loss: 1.1393
# Epoch 42/50
# 188/188 [==============================] - 0s 842us/step - loss: 0.9278 - val_loss: 1.1394
# Epoch 43/50
# 188/188 [==============================] - 0s 850us/step - loss: 0.9276 - val_loss: 1.1395
# Epoch 44/50
# 188/188 [==============================] - 0s 845us/step - loss: 0.9275 - val_loss: 1.1396
# Epoch 45/50
# 188/188 [==============================] - 0s 842us/step - loss: 0.9273 - val_loss: 1.1398
# Epoch 46/50
# 188/188 [==============================] - 0s 836us/step - loss: 0.9272 - val_loss: 1.1399
# Epoch 47/50
# 188/188 [==============================] - 0s 880us/step - loss: 0.9271 - val_loss: 1.1400
# Epoch 48/50
# 188/188 [==============================] - 0s 853us/step - loss: 0.9270 - val_loss: 1.1401
# Epoch 49/50
# 188/188 [==============================] - 0s 852us/step - loss: 0.9268 - val_loss: 1.1401
# Epoch 50/50
# 188/188 [==============================] - 0s 853us/step - loss: 0.9267 - val_loss: 1.1404
#
# Final test eval on different site:
# 350/350 [==============================] - 0s 483us/step - loss: 1.5075

# %%
# save the model
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)

# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
model.save(os.path.join(model_path,'ssrd_ql_model.h5'))

# %%
# reload the saved model
model = load_model(os.path.join(model_path,'ssrd_ql_model.h5'), custom_objects = {"_qloss": QuantileLoss})

# predict on the test set
y_test_pre = model.predict(x_test)

# Show results with correlation matrix
df_test = x_test_df.reset_index().drop(["lat","lon"],axis=1).set_index("time")
df_test["poa"] = y_test_df.reset_index().drop(["lat","lon"],axis=1).set_index("time").poa
df_test["res"] = (y_test_pre* y_std.values[1] + y_mean.values[1])
df_test["y_test_pre"] = df_test["res"] + df_test.ssrd
df_test.corr()
# Out:
# 350/350 [==============================] - 0s 428us/step
#                 ssrd       tcc       t2m       poa       res  y_test_pre
# ssrd        1.000000 -0.084107  0.059241  0.930417 -0.061792    0.998957
# tcc        -0.084107  1.000000  0.079517 -0.118646 -0.291835   -0.097608
# t2m         0.059241  0.079517  1.000000  0.051362  0.039695    0.061163
# poa         0.930417 -0.118646  0.051362  1.000000 -0.001723    0.931998
# res        -0.061792 -0.291835  0.039695 -0.001723  1.000000   -0.016151
# y_test_pre  0.998957 -0.097608  0.061163  0.931998 -0.016151    1.000000

# %%
pd.plotting.scatter_matrix(df_test[["ssrd","tcc","t2m","poa"]])
# Out:
# array([[<AxesSubplot: xlabel='ssrd', ylabel='ssrd'>,
#         <AxesSubplot: xlabel='tcc', ylabel='ssrd'>,
#         <AxesSubplot: xlabel='t2m', ylabel='ssrd'>,
#         <AxesSubplot: xlabel='poa', ylabel='ssrd'>],
#        [<AxesSubplot: xlabel='ssrd', ylabel='tcc'>,
#         <AxesSubplot: xlabel='tcc', ylabel='tcc'>,
#         <AxesSubplot: xlabel='t2m', ylabel='tcc'>,
#         <AxesSubplot: xlabel='poa', ylabel='tcc'>],
#        [<AxesSubplot: xlabel='ssrd', ylabel='t2m'>,
#         <AxesSubplot: xlabel='tcc', ylabel='t2m'>,
#         <AxesSubplot: xlabel='t2m', ylabel='t2m'>,
#         <AxesSubplot: xlabel='poa', ylabel='t2m'>],
#        [<AxesSubplot: xlabel='ssrd', ylabel='poa'>,
#         <AxesSubplot: xlabel='tcc', ylabel='poa'>,
#         <AxesSubplot: xlabel='t2m', ylabel='poa'>,
#         <AxesSubplot: xlabel='poa', ylabel='poa'>]], dtype=object)

# %%
# Show results on total dataset
df_test = x_test_df.reset_index().drop(["lat","lon","tcc"],axis=1).set_index("time")
df_test["poa"] = y_test_df.reset_index().drop(["lat","lon"],axis=1).set_index("time").poa
df_test["res"] = (y_test_pre* y_std.values[1] + y_mean.values[1])
df_test["y_test_pre"] = df_test["res"] + df_test.ssrd

df_plot = df_test
df_plot.plot(figsize=(10,5))
plt.xticks(rotation=45)
# Out:
# (array([449729, 451416, 453624, 455832, 457992, 460176, 460919]),
#  [Text(449729, 0, ''),
#   Text(451416, 0, 'Jul'),
#   Text(453624, 0, 'Oct'),
#   Text(455832, 0, 'Jan\n2022'),
#   Text(457992, 0, 'Apr'),
#   Text(460176, 0, 'Jul'),
#   Text(460919, 0, '')])

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True,figsize=(10,5))

# Compare against input ssrd values
ax1.scatter(x=df_test.ssrd,y=df_test.poa)
p1 = max(max(df_test.poa), max(df_test.ssrd))
p2 = min(min(df_test.poa), min(df_test.ssrd))
ax1.plot([p1, p2], [p1, p2], 'r-')
ax1.set_xlabel("ERA5")
ax1.set_ylabel("GHI")
ax1.set_title("ERA5 vs Actual")

# Compare against input ssrd values
ax2.scatter(df_test.y_test_pre,df_test.ssrd)
p1 = max(max(df_test.y_test_pre), max(df_test.ssrd))
p2 = min(min(df_test.y_test_pre), min(df_test.ssrd))
ax2.plot([p1, p2], [p1, p2], 'r-')
ax2.set_xlabel("Predicted")
ax2.set_title("Predicted vs ERA5")

# Compare against y actual
ax3.scatter(df_test.y_test_pre,df_test.poa)
p1 = max(max(df_test.y_test_pre), max(df_test.poa))
p2 = min(min(df_test.y_test_pre), min(df_test.poa))
ax3.plot([p1, p2], [p1, p2], 'r-')
ax3.set_xlabel("Predicted")
ax3.set_title("Predicted vs Actual")
# Out:
# Text(0.5, 1.0, 'Predicted vs Actual')

# %%
### STD
#plot the results
df_test = x_test_df_std.reset_index().drop(["lat","lon"],axis=1).set_index("time")
df_test["poa"] = y_test_df_std.reset_index().drop(["lat","lon"],axis=1).set_index("time").poa
df_test["res"] = y_test_pre
df_test["pred"] = df_test.res + df_test.ssrd

df_plot = df_test[800:1000]
df_plot.plot(figsize=(10,5))
plt.xticks(rotation=45)
# Out:
# (array([-0.06, -0.04, -0.02,  0.  ,  0.02,  0.04,  0.06]),
#  [Text(-0.06, 0, '−0.06'),
#   Text(-0.039999999999999994, 0, '−0.04'),
#   Text(-0.019999999999999997, 0, '−0.02'),
#   Text(0.0, 0, '0.00'),
#   Text(0.020000000000000004, 0, '0.02'),
#   Text(0.04000000000000001, 0, '0.04'),
#   Text(0.06, 0, '0.06')])

# %%
df_plot = df_test[500:1000]
df_plot.plot(figsize=(10,5))
plt.xticks(rotation=45)
# Out:
# (array([450229, 450696, 450728]),
#  [Text(450229, 0, ''), Text(450696, 0, '01\nJun\n2021'), Text(450728, 0, '')])
